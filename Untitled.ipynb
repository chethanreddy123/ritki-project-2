# %%
from pandas import read_excel
from matplotlib import pyplot
series = read_excel('Inputs/Preprocessed_files/Average_Demand.xlsx', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19424\3038275725.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_excel('Inputs/Preprocessed_files/Average_Demand.xlsx', header=0, index_col=0, parse_dates=True, squeeze=True)
